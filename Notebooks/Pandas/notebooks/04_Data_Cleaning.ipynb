# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv("../../../Data/sales.csv")
products = pd.read_csv("../../../Data/products.csv")
stores = pd.read_csv("../../../Data/stores.csv")
category = pd.read_csv("../../../Data/category.csv")
warranty = pd.read_csv("../../../Data/warranty.csv")

# %% [markdown]
# Find missing values in every dataset.

# %%
sales.isnull().sum()
# Out:
# sale_id       0
# sale_date     0
# store_id      0
# product_id    0
# quantity      0
# dtype: int64

# %% [markdown]
#  Find duplicate records in the Sales dataset.

# %%
sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Rename all column names using snake_case format.

# %%
sales.columns
# Out:
# Index(['sale_id', 'sale_date', 'store_id', 'product_id', 'quantity'], dtype='object')

# %% [markdown]
# # Note:
# # All column names are already in snake_case format.
# # No renaming is required.

# %% [markdown]
# Create a cleaned version of the Sales dataset named clean_sales which is ready for further analysis

# %%
clean_sales = sales.copy()

# Remove duplicate rows
clean_sales = clean_sales.drop_duplicates()

# Verify missing values
clean_sales.isnull().sum()

clean_sales
# Out:
#             sale_id   sale_date store_id product_id  quantity
# 0        OID-358365  2021-09-16    ST-33       P-44         1
# 1        OID-358510  2022-01-28    ST-33       P-44         1
# 2        OID-358525  2021-11-26    ST-33       P-44         1
# 3        OID-358591  2021-09-15    ST-33       P-44         1
# 4        OID-358601  2022-02-07    ST-33       P-44         1
# ...             ...         ...      ...        ...       ...
# 1040186  OID-358351  2022-08-11    ST-33       P-48         1
# 1040187  OID-358352  2022-02-06    ST-33       P-49         1
# 1040188  OID-358353  2022-05-27    ST-33       P-49         1
# 1040189  OID-358354  2022-03-22    ST-33       P-49         1
# 1040190  OID-358355  2022-07-19    ST-33       P-49         1
#
# [1040191 rows x 5 columns]

# %% [markdown]
# # Business Insight:
#  Data cleaning ensures high-quality, trustworthy data,
#  enabling accurate insights and better business decisions.
