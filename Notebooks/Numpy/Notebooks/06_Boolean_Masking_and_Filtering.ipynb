# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv("../../../Data/Sales.csv")

# %%
quantity = sales["quantity"].to_numpy()

# %%
# Display all sales where the Quantity is greater than 2

# %%
quantity > 2
# Out:
# array([False, False, False, ..., False, False, False])

# %%
quantity[quantity > 2]
# Out:
# array([3, 3, 3, ..., 3, 3, 3], dtype=int64)

# %%
# Display all sales where the Quantity is equal to 1

# %%
quantity[quantity == 1]
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
# Count the total number of sales where the Quantity is greater than the average Quantity

# %%
len(quantity[quantity > np.mean(quantity)])
# Out:
# 98367

# %%
# Replace every Quantity value greater than 4 with 4 using NumPy

# %%
replaced_quantity = quantity.copy()

replaced_quantity[replaced_quantity > 4] = 4

print(replaced_quantity)
# Out:
# [1 1 1 ... 1 1 1]

# %%
 
print(np.unique(replaced_quantity))   # After change
# Out:
# [1 2 3 4]

# %%
print(np.unique(quantity))   # Before change
# Out:
# [1 2 3 4 5]

# %%
# Create a filtered NumPy matrix containing only high-volume sales (Quantity > Average Quantity) and prepare it for further business analysis.

# %%
quantity > np.average(quantity)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
matrix =sales.to_numpy()

# %%
quantity[quantity > np.mean(quantity)]
# Out:
# array([2, 2, 2, ..., 2, 3, 2], dtype=int64)

# %%
matrix[quantity > np.mean(quantity)]
# Out:
# array([['OID-398187', '2019-12-21', 'ST-30', 'P-20', 2],
#        ['OID-398189', '2020-04-08', 'ST-30', 'P-21', 2],
#        ['OID-398193', '2020-02-01', 'ST-30', 'P-21', 2],
#        ...,
#        ['OID-1048548', '2019-01-02', 'ST-1', 'P-16', 2],
#        ['OID-1048550', '2019-01-02', 'ST-1', 'P-16', 3],
#        ['OID-1048551', '2019-01-02', 'ST-1', 'P-16', 2]], dtype=object)

# %%
print("Business Insight:")
print("This filtered dataset contains only high-volume sales, helping managers focus on the best-performing transactions for analysis and decision-making.")
# Out:
# Business Insight:
# This filtered dataset contains only high-volume sales, helping managers focus on the best-performing transactions for analysis and decision-making.
